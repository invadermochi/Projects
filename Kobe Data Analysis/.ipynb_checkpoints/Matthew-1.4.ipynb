# %% [markdown]
# # Research Question

# %% [markdown]
# Which starting lineup was Kobe Bryant the most successful; we define new lineups as major changes where 1 or more players starting players (the 5 starters of the team) are swapped out. We will quantify this by examining Kobe Bryant's average points scored per minute within a certain lineup.

# %% [markdown]
# # Hypotheses

# %% [markdown]
# 1. Kobe will perform better in teams where he has lots of experience with (the lineups he had the most games played with).

# %% [markdown]
# # Datasets

# %% [markdown]
# - Dataset Name: General Stats of Kobe Bryant's Career
# - Links to the dataset:
# 1. https://www.basketball-reference.com/players/b/bryanko01.html
# 2. https://www.basketball-reference.com/players/b/bryanko01/gamelog/1997/
# 3. https://www.basketball-reference.com/boxscores/199611010LAL.html
# - Number of observations: 1198
#
# Using these links, I scraped all of the games that Kobe has started in (part of the starting lineup) by recursively extracting tables from the three websites above. While the list of his games goes up to around 1500, after cleaning the data, it ends up being just below 1200.

# %% [markdown]
# # Setup

# %%
# Imports 
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import copy

import seaborn as sns
sns.set()
sns.set_context('talk')

import warnings
warnings.filterwarnings('ignore')

import patsy
import statsmodels.api as sm
import scipy.stats as stats
from scipy.stats import ttest_ind, chisquare, normaltest

import requests
import bs4
from bs4 import BeautifulSoup
import re

# %% [markdown]
# # Data Gathering and Cleaning

# %%
def convert_to_PPM(points, minutes): 
    
    """Converts minutes to a float, divide points by float to get points per minute by Kobe in a game

    Parameters:
    points (string): Points Kobe made in a game
    minutes (string): Minutes Kobe played in a game
    
    Returns:
    float: Points per minute Kobe made in a game

   """
    
    indexN = minutes.index(':')
    
    minute = minutes[0:indexN]
    second = minutes[indexN+1:]
    
    seconds = int(minute)*60 + int(second)
    floatMinutes = seconds/60
    
    return float(points)/floatMinutes

# %%
#Retrieving the page for the table with all of Kobe's games listed by year
site = "https://www.basketball-reference.com/players/b/bryanko01.html"
page = requests.get(site)
soup = BeautifulSoup(page.content, "html.parser")

#Scraping the page to get all of the links to the games Kobe's played by year

table = soup.find_all(href=re.compile("/players/b/bryanko01/gamelog/"))

links = []

for html in table:
    links.append("https://www.basketball-reference.com" + html['href'])
    
#Truncating the list as duplicate links were listed
del links[20:]

# %%
#Retrieving every game Kobe has played based on the links previously retrieved
game_links = []

for year in links:
    tempPage = requests.get(year)
    tempSoup = BeautifulSoup(tempPage.content, "html.parser")
    
    tempTable = tempSoup.find_all(href=re.compile("/boxscores/"))
    
    for tempHtml in tempTable:
        game_links.append("https://www.basketball-reference.com" + tempHtml['href'])

# %%
#Cleaning the links that have no data
game_links[:] = [link for link in game_links if "https://www.basketball-reference.com/boxscores/" != link]

# %%
#Retrieving the correct team info as both teams show up on the website
games = []

#Getting the BeautifulSoup Table, converting to Dataframe, and putting it in a list
for game in game_links:
    tempPage = requests.get(game)
    tempSoup = BeautifulSoup(tempPage.content, "html.parser")
    
    for caption in tempSoup.find_all('caption'):
        if 'Los Angeles Lakers' in caption.get_text():
            tempGame = caption.find_parent('table')
            gameDF = pd.read_html(str(tempGame))[0]
        
            #Dropping all rows that do not contain starters
            gameDF = gameDF.drop(gameDF.index[5:])
        
            #Correcting the column names
            gameDF.columns=['Starters', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', '+/-']
        
            #Adding the table to the list if Kobe started in the game
            if(gameDF["Starters"].str.contains("Kobe Bryant").any()):
                games.append(gameDF)
            break

# %%
games[0]
# Out:
#            Starters     MP  FG FGA   FG% 3P 3PA   3P% FT FTA  ... ORB DRB TRB  \
# 0  Shaquille O'Neal  36:45  13  23  .565  0   0   NaN  5  10  ...   4   6  10
# 1     Nick Van Exel  32:59   8  13  .615  3   6  .500  0   0  ...   1   4   5
# 2       Kobe Bryant  31:45   5  11  .455  0   3  .000  2   3  ...   1   2   3
# 3       Eddie Jones  30:13   3  11  .273  0   4  .000  0   0  ...   0   3   3
# 4    Elden Campbell  17:56   2   4  .500  0   0   NaN  0   0  ...   4   3   7
#
#   AST STL BLK TOV PF PTS  +/-
# 0   3   0   2   1  3  31  +13
# 1   6   4   0   3  0  19  +11
# 2   2   2   1   3  1  12  +10
# 3   2   3   0   2  2   6   +1
# 4   1   0   1   1  2   4   +3
#
# [5 rows x 21 columns]

# %%
#Making a list of lists of lineups 
lineups = []

for game in games:
    lineup = []
    
    game.set_index("Starters", inplace=True)
    lineup.append(game.index.tolist())
    lineup.append(convert_to_PPM(game.loc["Kobe Bryant"].PTS, game.loc["Kobe Bryant"].MP))
    
    lineups.append(lineup)

# %%
#Sorting lineups alphabetically, creating a list of unique lineups, averaging the PPM of the unique lineups
lineups[0].append(1)
lineups[0][0].sort()
uniqueLineups = [lineups[0]]


for lineup in lineups:
    
    #Skip first iteration 
    if(lineups.index(lineup) == 0):
        continue

    lineup[0].sort()
    count = 0
    
    for(players in uniqueLineups):
        count += 1
        
        if(lineup[0] == players[0]):
            players[1] += lineup[1]
            players[2] += 1
            break

        if(count == len(uniqueLineups)):
            newlineup = []
            newlineup.append(lineup[0])
            newlineup.append(lineup[1])
            newlineup.append(1)
            uniqueLineups.append(newlineup)
            break

# %% [markdown]
# # Data Analysis and Results

# %%
mostCommonLineup = uniqueLineups[0]

for lineups in uniqueLineups:
    if(lineups[2] > mostCommonLineup[2]):
        mostCommonLineup = lineups
        
print(mostCommonLineup)
# Out:
# [['Andrew Bynum', 'Derek Fisher', 'Kobe Bryant', 'Metta World Peace', 'Pau Gasol'], 80.25794852971109, 112]

# %% [markdown]
# As you can see, uniqueLineups is a list of all unique lineups Kobe Bryant has played in. The first index contains a list of names of the lineup. The second index contains the summed total points per minute Kobe made with that lineup. The third variable shows how many times Kobe played with that lineup. Next, I will do some exploratory analysis on the collected data through dataframes.

# %%
dfLineups = pd.DataFrame(uniqueLineups, columns=["Starters", "Total Kobe PPM", "Times Played"])
dfLineups.set_index("Starters", inplace=True)

# %% [markdown]
# In order to get a fair idea on how Kobe's PPM varied between groups, I divided Kobe's total PPM by the number of times he playe with the lineup.

# %%
#Averaging Kobe's PPM based on how many times he played with the team
dfLineups["Kobe PPM Average With Lineup"] = dfLineups["Total Kobe PPM"]/dfLineups["Times Played"]
dfLineups.head()
# Out:
#                                                     Total Kobe PPM  \
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Sasha Vu...        1.300867
# [Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar...        2.176970
# [Chris Duhon, Dwight Howard, Jordan Hill, Kobe ...        1.031519
# [Derek Fisher, Didier Ilunga-Mbenga, Kobe Bryan...        2.049285
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...        0.996857
#
#                                                     Times Played  \
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Sasha Vu...             1
# [Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar...             2
# [Chris Duhon, Dwight Howard, Jordan Hill, Kobe ...             1
# [Derek Fisher, Didier Ilunga-Mbenga, Kobe Bryan...             2
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...             1
#
#                                                     Kobe PPM Average With Lineup
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Sasha Vu...                      1.300867
# [Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar...                      1.088485
# [Chris Duhon, Dwight Howard, Jordan Hill, Kobe ...                      1.031519
# [Derek Fisher, Didier Ilunga-Mbenga, Kobe Bryan...                      1.024643
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...                      0.996857

# %%
dfLineups.sort_values("Times Played", ascending=False)
# Out:
#                                                     Total Kobe PPM  \
# Starters
# [Andrew Bynum, Derek Fisher, Kobe Bryant, Metta...       80.257949
# [A.C. Green, Glen Rice, Kobe Bryant, Ron Harper...       32.155771
# [Caron Butler, Chris Mihm, Chucky Atkins, Kobe ...       29.943371
# [Derek Fisher, Kobe Bryant, Rick Fox, Samaki Wa...       32.472603
# [Derek Fisher, Kobe Bryant, Lamar Odom, Metta W...       32.109344
# ...                                                            ...
# [Derek Fisher, Devean George, Kobe Bryant, Robe...        0.631579
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...        0.615970
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...        0.589549
# [Kobe Bryant, Kwame Brown, Lamar Odom, Ronny Tu...        0.588697
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...        0.143971
#
#                                                     Times Played  \
# Starters
# [Andrew Bynum, Derek Fisher, Kobe Bryant, Metta...           112
# [A.C. Green, Glen Rice, Kobe Bryant, Ron Harper...            54
# [Caron Butler, Chris Mihm, Chucky Atkins, Kobe ...            46
# [Derek Fisher, Kobe Bryant, Rick Fox, Samaki Wa...            45
# [Derek Fisher, Kobe Bryant, Lamar Odom, Metta W...            44
# ...                                                          ...
# [Derek Fisher, Devean George, Kobe Bryant, Robe...             1
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...             1
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...             1
# [Kobe Bryant, Kwame Brown, Lamar Odom, Ronny Tu...             1
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...             1
#
#                                                     Kobe PPM Average With Lineup
# Starters
# [Andrew Bynum, Derek Fisher, Kobe Bryant, Metta...                      0.716589
# [A.C. Green, Glen Rice, Kobe Bryant, Ron Harper...                      0.595477
# [Caron Butler, Chris Mihm, Chucky Atkins, Kobe ...                      0.650943
# [Derek Fisher, Kobe Bryant, Rick Fox, Samaki Wa...                      0.721613
# [Derek Fisher, Kobe Bryant, Lamar Odom, Metta W...                      0.729758
# ...                                                                          ...
# [Derek Fisher, Devean George, Kobe Bryant, Robe...                      0.631579
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...                      0.615970
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...                      0.589549
# [Kobe Bryant, Kwame Brown, Lamar Odom, Ronny Tu...                      0.588697
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...                      0.143971
#
# [152 rows x 3 columns]

# %%
dfLineups.sort_values("Kobe PPM Average With Lineup", ascending=False, inplace=True)
dfLineups
# Out:
#                                                     Total Kobe PPM  \
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Sasha Vu...        1.300867
# [Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar...        2.176970
# [Chris Duhon, Dwight Howard, Jordan Hill, Kobe ...        1.031519
# [Derek Fisher, Didier Ilunga-Mbenga, Kobe Bryan...        2.049285
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...        0.996857
# ...                                                            ...
# [Derek Harper, Kobe Bryant, Robert Horry, Shaqu...        0.327273
# [Kobe Bryant, Pau Gasol, Robert Sacre, Steve Bl...        0.322196
# [A.C. Green, Derek Fisher, Glen Rice, Kobe Brya...        0.627978
# [Eddie Jones, Kobe Bryant, Nick Van Exel, Rober...        0.250149
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...        0.143971
#
#                                                     Times Played  \
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Sasha Vu...             1
# [Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar...             2
# [Chris Duhon, Dwight Howard, Jordan Hill, Kobe ...             1
# [Derek Fisher, Didier Ilunga-Mbenga, Kobe Bryan...             2
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...             1
# ...                                                          ...
# [Derek Harper, Kobe Bryant, Robert Horry, Shaqu...             1
# [Kobe Bryant, Pau Gasol, Robert Sacre, Steve Bl...             1
# [A.C. Green, Derek Fisher, Glen Rice, Kobe Brya...             2
# [Eddie Jones, Kobe Bryant, Nick Van Exel, Rober...             1
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...             1
#
#                                                     Kobe PPM Average With Lineup
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Sasha Vu...                      1.300867
# [Jordan Farmar, Kobe Bryant, Kwame Brown, Lamar...                      1.088485
# [Chris Duhon, Dwight Howard, Jordan Hill, Kobe ...                      1.031519
# [Derek Fisher, Didier Ilunga-Mbenga, Kobe Bryan...                      1.024643
# [Chris Mihm, Chucky Atkins, Jumaine Jones, Kobe...                      0.996857
# ...                                                                          ...
# [Derek Harper, Kobe Bryant, Robert Horry, Shaqu...                      0.327273
# [Kobe Bryant, Pau Gasol, Robert Sacre, Steve Bl...                      0.322196
# [A.C. Green, Derek Fisher, Glen Rice, Kobe Brya...                      0.313989
# [Eddie Jones, Kobe Bryant, Nick Van Exel, Rober...                      0.250149
# [Ed Davis, Jeremy Lin, Jordan Hill, Kobe Bryant...                      0.143971
#
# [152 rows x 3 columns]

# %% [markdown]
# Lineups where Kobe only played with them once greatly misrepresent how the lineup affected his performance; they are artificially inflated. In order to lessen these effects, I will show the data where he played with the lineup at least 3 times. I chose three times because even at 2 times played, there were many data points that were misrepresentational. Also, choosing to show these data halved the amount of data there was (this could be a good or bad thing).

# %%
dfLineups[dfLineups["Times Played"] > 2]
# Out:
#                                                     Total Kobe PPM  \
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Luke Wal...       18.018037
# [Chris Mihm, Kobe Bryant, Kwame Brown, Lamar Od...       20.395699
# [Andrew Bynum, Kobe Bryant, Lamar Odom, Maurice...        2.734621
# [Caron Butler, Chris Mihm, Chucky Atkins, Kobe ...        2.652106
# [Derek Fisher, Kobe Bryant, Rick Fox, Robert Ho...        7.741503
# ...                                                            ...
# [Dwight Howard, Jodie Meeks, Kobe Bryant, Pau G...        1.581101
# [Derek Harper, Eddie Jones, Kobe Bryant, Shaqui...        5.643433
# [Corie Blount, Derek Fisher, Eddie Jones, Kobe ...        1.460556
# [Derek Fisher, Glen Rice, J.R. Reid, Kobe Bryan...        4.545713
# [Jodie Meeks, Jordan Hill, Kobe Bryant, Pau Gas...        1.716504
#
#                                                     Times Played  \
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Luke Wal...            19
# [Chris Mihm, Kobe Bryant, Kwame Brown, Lamar Od...            22
# [Andrew Bynum, Kobe Bryant, Lamar Odom, Maurice...             3
# [Caron Butler, Chris Mihm, Chucky Atkins, Kobe ...             3
# [Derek Fisher, Kobe Bryant, Rick Fox, Robert Ho...             9
# ...                                                          ...
# [Dwight Howard, Jodie Meeks, Kobe Bryant, Pau G...             3
# [Derek Harper, Eddie Jones, Kobe Bryant, Shaqui...            11
# [Corie Blount, Derek Fisher, Eddie Jones, Kobe ...             3
# [Derek Fisher, Glen Rice, J.R. Reid, Kobe Bryan...            10
# [Jodie Meeks, Jordan Hill, Kobe Bryant, Pau Gas...             4
#
#                                                     Kobe PPM Average With Lineup
# Starters
# [Kobe Bryant, Kwame Brown, Lamar Odom, Luke Wal...                      0.948318
# [Chris Mihm, Kobe Bryant, Kwame Brown, Lamar Od...                      0.927077
# [Andrew Bynum, Kobe Bryant, Lamar Odom, Maurice...                      0.911540
# [Caron Butler, Chris Mihm, Chucky Atkins, Kobe ...                      0.884035
# [Derek Fisher, Kobe Bryant, Rick Fox, Robert Ho...                      0.860167
# ...                                                                          ...
# [Dwight Howard, Jodie Meeks, Kobe Bryant, Pau G...                      0.527034
# [Derek Harper, Eddie Jones, Kobe Bryant, Shaqui...                      0.513039
# [Corie Blount, Derek Fisher, Eddie Jones, Kobe ...                      0.486852
# [Derek Fisher, Glen Rice, J.R. Reid, Kobe Bryan...                      0.454571
# [Jodie Meeks, Jordan Hill, Kobe Bryant, Pau Gas...                      0.429126
#
# [79 rows x 3 columns]
